# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (2.13.0)
# Requirement already satisfied: packaging in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (4.24.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.33.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (1.57.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: setuptools in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.4.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.22.0)
# Requirement already satisfied: urllib3<2.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.26.16)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.2.2)

# %%
# !pip install scikit-plot
# Out:
# Requirement already satisfied: scikit-plot in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from scikit-plot) (3.7.2)
# Requirement already satisfied: joblib>=0.10 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from scikit-plot) (1.3.1)
# Requirement already satisfied: scikit-learn>=0.18 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from scikit-plot) (1.11.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (4.42.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: numpy>=1.20 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (23.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Users/sanjayakumar/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import pandas as pd #  Imports the pandas library, a powerful library for data manipulation and analysis, and aliases it as pd.
import numpy as np # Imports the numpy library, a library for numerical operations and working with arrays, and aliases it as np.
import scikitplot #  Imports the scikit-plot library, a library for creating visualizations related to machine learning.
import random #  Imports the random module, which contains various functions for generating random numbers.
import seaborn as sns # Imports the seaborn library, a library for creating statistical graphics, and aliases it as sns.
import keras # Imports the Keras library, a high-level neural networks API built on top of TensorFlow.
import os #  Imports the os module, which provides a way to interact with the operating system.
from matplotlib import pyplot # Imports the pyplot module from the matplotlib library, which is used for creating plots and charts.
import matplotlib.pyplot as plt #  Imports the pyplot module from the matplotlib library and aliases it as plt.
import tensorflow as tf # Imports the TensorFlow library, a popular library for machine learning and deep learning, and aliases it as tf.
from tensorflow.keras.utils import to_categorical #  Imports the to_categorical function from TensorFlow's Keras utils, which is used to convert integer labels to one-hot vectors.

import warnings #  Imports the warnings module, which allows handling and filtering of warning messages.
from tensorflow.keras.models import Sequential # Imports the Sequential class from TensorFlow's Keras models, which is a linear stack of layers for building neural networks.

from keras.callbacks import EarlyStopping # Imports the EarlyStopping class from Keras callbacks, which can be used to stop training when a monitored quantity has stopped improving.

from keras import regularizers # Imports the regularizers module from Keras, which includes regularization functions like L1 and L2.
from keras.callbacks import ModelCheckpoint,EarlyStopping # Imports the ModelCheckpoint and EarlyStopping classes from Keras callbacks.
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax # Imports various optimization algorithms from TensorFlow's Keras optimizers, including Adam, RMSprop, Stochastic Gradient Descent (SGD), and Adamax.

from keras.preprocessing.image import ImageDataGenerator,load_img # Imports the ImageDataGenerator and load_img functions from Keras' image preprocessing module, which are used for data augmentation and loading images.

from keras.utils import plot_model #  Imports the plot_model function from Keras' visualization utilities, which is used to plot a neural network model.

from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization,MaxPooling2D,Activation,Input # Imports various layer types from Keras' layers module, which are used to build neural networks.

from sklearn.model_selection import train_test_split # Imports the train_test_split function from scikit-learn's model selection module, which is used to split a dataset into training and testing sets.

from sklearn.preprocessing import StandardScaler # Imports the StandardScaler class from scikit-learn's preprocessing module, which is used to standardize features by removing the mean and scaling to unit variance.

warnings.simplefilter("ignore") # Sets the warnings filter to "ignore", which means that no warning messages will be displayed during the execution of the script.

from keras.models import Model #  Imports the Model class from Keras models, which is a base class for Keras models and can be used to create more complex neural network architectures.

from sklearn.model_selection import train_test_split # Imports the train_test_split function from scikit-learn's model selection module, which is used to split a dataset into training and testing sets.

from sklearn.metrics import accuracy_score # Imports the accuracy_score function from scikit-learn's metrics module, which is used to compute the accuracy of a classifier's predictions.

from keras.regularizers import l1, l2 # Imports the L1 and L2 regularization functions from Keras' regularizers module, which can be used to apply penalties to the weights of a neural network during training to reduce overfitting.

import plotly.express as px # Imports the Plotly Express library, a high-level interface for creating interactive plots and charts, and aliases it as px.

from matplotlib import pyplot as plt # Imports the pyplot module from the matplotlib library and aliases it as plt, which is used for creating plots and charts.

from sklearn.metrics import confusion_matrix #  Imports the confusion_matrix function from scikit-learn's metrics module, which is used to compute the confusion matrix of a classifier's predictions.

from sklearn.metrics import classification_report # Imports the classification_report function from scikit-learn's metrics module, which is used to generate a text report showing the main classification metrics like precision, recall, and F1-score.

# %%
#load data

data = pd.read_csv("fer2013_changed.csv")
data.shape
# Out:
# (35887, 3)

# %%
data.isnull().sum()
# Out:
# emotion    0
# pixels     0
# Usage      0
# dtype: int64

# %%
data.head()
# Out:
#    emotion                                             pixels     Usage
# 0        0  70 80 82 72 58 58 60 63 54 58 60 48 89 115 121...  Training
# 1        0  151 150 147 155 148 133 111 140 170 174 182 15...  Training
# 2        0  30 24 21 23 25 25 49 67 84 103 120 125 130 139...  Training
# 3        0  123 125 124 142 209 226 234 236 231 232 235 22...  Training
# 4        0  8 9 14 21 26 32 37 46 52 62 72 70 71 73 76 83 ...  Training

# %%
data['emotion'].value_counts()
# Out:
# 2    12991
# 4     6198
# 3     6077
# 0     5500
# 1     5121
# Name: emotion, dtype: int64

# %%
# Data preprocessing

CLASS_LABELS = ['Anger','Fear','Happy','Sadness', 'Neutral']

fig = px.bar(
    x = CLASS_LABELS,
    y = [list(data['emotion']).count(i) for i in np.unique(data['emotion'])],

    color = np.unique(data['emotion']),
    color_continuous_scale = "Emrld")

fig.update_xaxes(title = "Emotion")
fig.update_yaxes(title = "Number of Image")
fig.update_layout(showlegend = True,

                  title = {
                      'text': 'Train Data Distribution',
                      'y': 0.95,
                      'x': 0.5,
                      'xanchor':'center',
                      'yanchor':'top'

                  }
                 )

fig.show()
# Out:
# <div>                            <div id="bedf70e3-94e3-4f7b-a51f-9984bb022602" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bedf70e3-94e3-4f7b-a51f-9984bb022602")) {                    Plotly.newPlot(                        "bedf70e3-94e3-4f7b-a51f-9984bb022602",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,1,2,3,4],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Anger","Fear","Happy","Sadness","Neutral"],"xaxis":"x","y":[5500,5121,12991,6077,6198],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker": ...

# %%
data = data.sample(frac = 1) # permanently shuffling the data

# %%
# one hot encoding
labels = to_categorical(data[['emotion']], num_classes = 5)

# %%
train_pixels = data["pixels"].astype(str).str.split(" ").tolist()
train_pixels = np.uint8(train_pixels) #converting pixel values to 8-bit unsigned integers

# %%
# standardization
pixels = train_pixels.reshape((35887*2304,1)) #reshaping the numpy array

# %%
scaler = StandardScaler()
pixels = scaler.fit_transform(pixels)

# %%
# reshaping
pixels = train_pixels.reshape((35887, 48, 48, 1)) #reshaping into 48 * 48

# %%
# train test validataion

X_train, X_test, y_train, y_test = train_test_split(pixels, labels, test_size =0.1, shuffle = False)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.1, shuffle = False)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
# Out:
# (29068, 48, 48, 1)
# (3589, 48, 48, 1)
# (3230, 48, 48, 1)

# %%
plt.figure(figsize = (15,23))
label_dict = {0 : 'Angry', 1 : 'Fear', 2 : 'Happiness', 3 : 'Sad', 4 : 'Neutral'}

i = 1
for i in range(7):
    img = np.squeeze(X_train[i])

    plt.subplot(1,7,i+1)
    plt.imshow(img)
    index = np.argmax(y_train[i])
    plt.title(label_dict[index])

    plt.axis('off')
    i += 1
plt.show()

# %%
# Data augmentation

datagen = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    zoom_range = 0.2
)

valgen = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True,
    zoom_range = 0.2
)

# %%
datagen.fit(X_train)
valgen.fit(X_val)

# %%
train_generator = datagen.flow(X_train, y_train, batch_size = 64)

val_generator = datagen.flow(X_val, y_val, batch_size = 64)

# %% [markdown]
# # Design A Model

# %%
def cnn_model():

  model= tf.keras.models.Sequential() # Creates a new Sequential model object.
  model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1))) # Adds a 2D convolutional layer with 32 filters, a 3x3 kernel size, "same" padding, ReLU activation function, and an input shape of (48, 48, 1) for grayscale images.

  model.add(Conv2D(64,(3,3), padding='same', activation='relu' )) #  Adds another 2D convolutional layer with 64 filters, a 3x3 kernel size, "same" padding, and ReLU activation function.

  model.add(BatchNormalization()) # Adds a batch normalization layer to normalize the activations of the previous layer.
  model.add(MaxPool2D(pool_size=(2, 2))) # Adds a 2D max-pooling layer with a pool size of 2x2 to reduce the spatial dimensions of the input.
  model.add(Dropout(0.25)) # Adds a dropout layer with a rate of 0.25 to prevent overfitting by randomly setting a fraction of input units to 0 during training.

  '''
  The next four blocks of layers follow a similar pattern with varying numbers of filters, kernel sizes, and regularization:

    Conv2D layer
    BatchNormalization layer
    MaxPool2D layer
    Dropout layer
  '''

  model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
  model.add(BatchNormalization())
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(BatchNormalization())
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(BatchNormalization())
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
  model.add(BatchNormalization())
  model.add(MaxPool2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))

  model.add(Flatten())  # A flatten layer to convert the 3D output of the previous layer into a 1D array.
  model.add(Dense(256,activation = 'relu')) # A fully connected dense layer with 256 units and a ReLU activation function.
  model.add(BatchNormalization()) # Another batch normalization layer.
  model.add(Dropout(0.25)) #  Another dropout layer with a rate of 0.25.

  model.add(Dense(512,activation = 'relu')) #Another fully connected dense layer with 512 units and a ReLU activation function.
  model.add(BatchNormalization()) # Another batch normalization layer.
  model.add(Dropout(0.25)) #  Another dropout layer with a rate of 0.25.

  model.add(Dense(5, activation='softmax')) # The output layer of the model, which is a fully connected dense layer with 5 units (corresponding to the 5 emotion classes) and a softmax activation function.

  # Lastly, the model is compiled using the Adam optimizer with a learning rate of 0.0001, categorical crossentropy loss, and the accuracy metric:
  model.compile(
    optimizer = Adam(lr=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy'])
  return model # The function returns the compiled model, which can then be trained and evaluated using the training, validation, and test datasets.

'''
The cnn_model() function defines a convolutional neural network (CNN) model for emotion recognition using TensorFlow and Keras. The function creates a Sequential model and adds several layers to it, including convolutional, batch normalization, max-pooling, dropout, and dense layers. Finally, it compiles the model with the Adam optimizer, categorical crossentropy loss, and accuracy metric. Here's a breakdown of each layer and its purpose:
'''
# Out:
# "\nThe cnn_model() function defines a convolutional neural network (CNN) model for emotion recognition using TensorFlow and Keras. The function creates a Sequential model and adds several layers to it, including convolutional, batch normalization, max-pooling, dropout, and dense layers. Finally, it compiles the model with the Adam optimizer, categorical crossentropy loss, and accuracy metric. Here's a breakdown of each layer and its purpose:\n"

# %%
model = cnn_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.compile(
    optimizer = Adam(lr = 0.0001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 48, 48, 32)        320
#
#  conv2d_13 (Conv2D)          (None, 48, 48, 64)        18496
#
#  batch_normalization_14 (Ba  (None, 48, 48, 64)        256
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 24, 24, 64)        0
#  ng2D)
#
#  dropout_14 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 24, 24, 128)       204928
#
#  batch_normalization_15 (Ba  (None, 24, 24, 128)       512
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 12, 12, 128)       0
#  ng2D)
#
#  dropout_15 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_15 (Conv2D)          (None, 12, 12, 512)       590336
#
#  batch_normalization_16 (Ba  (None, 12, 12, 512)       2048
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 6, 6, 512)         0
#  ng2D)
#
#  dropout_16 (Dropout)        (None, 6, 6, 512)         0
#
#  conv2d_16 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_17 (Ba  (None, 6, 6, 512)         2048
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 3, 3, 512)         0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 3, 3, 512)         0
#
#  conv2d_17 (Conv2D)          (None, 3, 3, 512)         2359808
#
#  batch_normalization_18 (Ba  (None, 3, 3, 512)         2048
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 1, 1, 512)         0
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 1, 1, 512)         0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  batch_normalization_19 (Ba  (None, 256)               1024
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_7 (Dense)             (None, 512)               131584
#
#  batch_normalization_20 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_8 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 5809157 (22.16 MB)
# Trainable params: 5804165 (22.14 MB)
# Non-trainable params: 4992 (19.50 KB)
# _________________________________________________________________

# %%
# early stopping

checkpointer = [EarlyStopping(monitor = 'val_accuracy', verbose = 1, restore_best_weights = True,
                             mode = "max",patience = 5),

               ModelCheckpoint('AML/best_model.h5', monitor = "val_accuracy", verbose = 1,
                               save_best_only = True, mode = "max")
               ]

# %%
history = model.fit(train_generator,
                   epochs = 30,
                   batch_size = 64,
                   verbose = 1,
                   callbacks = [checkpointer],
                   validation_data = val_generator)
# Out:
# Epoch 1/30
# 455/455 [==============================] - ETA: 0s - loss: 6.3161 - accuracy: 0.2919
# Epoch 1: val_accuracy improved from -inf to 0.35697, saving model to AML/best_model.h5
# 455/455 [==============================] - 520s 1s/step - loss: 6.3161 - accuracy: 0.2919 - val_loss: 2.2121 - val_accuracy: 0.3570
# Epoch 2/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9816 - accuracy: 0.3330
# Epoch 2: val_accuracy did not improve from 0.35697
# 455/455 [==============================] - 562s 1s/step - loss: 1.9816 - accuracy: 0.3330 - val_loss: 1.9789 - val_accuracy: 0.3467
# Epoch 3/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9326 - accuracy: 0.3484
# Epoch 3: val_accuracy improved from 0.35697 to 0.35728, saving model to AML/best_model.h5
# 455/455 [==============================] - 539s 1s/step - loss: 1.9326 - accuracy: 0.3484 - val_loss: 1.9706 - val_accuracy: 0.3573
# Epoch 4/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9418 - accuracy: 0.3514
# Epoch 4: val_accuracy did not improve from 0.35728
# 455/455 [==============================] - 534s 1s/step - loss: 1.9418 - accuracy: 0.3514 - val_loss: 1.8625 - val_accuracy: 0.3517
# Epoch 5/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9545 - accuracy: 0.3565
# Epoch 5: val_accuracy did not improve from 0.35728
# 455/455 [==============================] - 566s 1s/step - loss: 1.9545 - accuracy: 0.3565 - val_loss: 2.2082 - val_accuracy: 0.3563
# Epoch 6/30
# 455/455 [==============================] - ETA: 0s - loss: 2.2392 - accuracy: 0.3941
# Epoch 6: val_accuracy improved from 0.35728 to 0.38978, saving model to AML/best_model.h5
# 455/455 [==============================] - 582s 1s/step - loss: 2.2392 - accuracy: 0.3941 - val_loss: 2.4211 - val_accuracy: 0.3898
# Epoch 7/30
# 455/455 [==============================] - ETA: 0s - loss: 2.3275 - accuracy: 0.4385
# Epoch 7: val_accuracy did not improve from 0.38978
# 455/455 [==============================] - 570s 1s/step - loss: 2.3275 - accuracy: 0.4385 - val_loss: 2.4567 - val_accuracy: 0.3851
# Epoch 8/30
# 455/455 [==============================] - ETA: 0s - loss: 2.2954 - accuracy: 0.4679
# Epoch 8: val_accuracy improved from 0.38978 to 0.47802, saving model to AML/best_model.h5
# 455/455 [==============================] - 555s 1s/step - loss: 2.2954 - accuracy: 0.4679 - val_loss: 2.1744 - val_accuracy: 0.4780
# Epoch 9/30
# 455/455 [==============================] - ETA: 0s - loss: 2.1428 - accuracy: 0.4878
# Epoch 9: val_accuracy did not improve from 0.47802
# 455/455 [==============================] - 562s 1s/step - loss: 2.1428 - accuracy: 0.4878 - val_loss: 2.3429 - val_accuracy: 0.4440
# Epoch 10/30
# 455/455 [==============================] - ETA: 0s - loss: 2.0759 - accuracy: 0.4991
# Epoch 10: val_accuracy did not improve from 0.47802
# 455/455 [==============================] - 519s 1s/step - loss: 2.0759 - accuracy: 0.4991 - val_loss: 2.0603 - val_accuracy: 0.4424
# Epoch 11/30
# 455/455 [==============================] - ETA: 0s - loss: 2.0151 - accuracy: 0.5058
# Epoch 11: val_accuracy did not improve from 0.47802
# 455/455 [==============================] - 516s 1s/step - loss: 2.0151 - accuracy: 0.5058 - val_loss: 2.1065 - val_accuracy: 0.4613
# Epoch 12/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9658 - accuracy: 0.5152
# Epoch 12: val_accuracy improved from 0.47802 to 0.51022, saving model to AML/best_model.h5
# 455/455 [==============================] - 520s 1s/step - loss: 1.9658 - accuracy: 0.5152 - val_loss: 1.9712 - val_accuracy: 0.5102
# Epoch 13/30
# 455/455 [==============================] - ETA: 0s - loss: 1.9184 - accuracy: 0.5233
# Epoch 13: val_accuracy did not improve from 0.51022
# 455/455 [==============================] - 524s 1s/step - loss: 1.9184 - accuracy: 0.5233 - val_loss: 1.9640 - val_accuracy: 0.4802
# Epoch 14/30
# 455/455 [==============================] - ETA: 0s - loss: 1.8933 - accuracy: 0.5258
# Epoch 14: val_accuracy improved from 0.51022 to 0.51950, saving model to AML/best_model.h5
# 455/455 [==============================] - 519s 1s/step - loss: 1.8933 - accuracy: 0.5258 - val_loss: 1.8350 - val_accuracy: 0.5195
# Epoch 15/30
# 455/455 [==============================] - ETA: 0s - loss: 1.8283 - accuracy: 0.5245
# Epoch 15: val_accuracy improved from 0.51950 to 0.52074, saving model to AML/best_model.h5
# 455/455 [==============================] - 488s 1s/step - loss: 1.8283 - accuracy: 0.5245 - val_loss: 1.8169 - val_accuracy: 0.5207
# Epoch 16/30
# 455/455 [==============================] - ETA: 0s - loss: 1.8205 - accuracy: 0.5309
# Epoch 16: val_accuracy improved from 0.52074 to 0.52755, saving model to AML/best_model.h5
# 455/455 [==============================] - 468s 1s/step - loss: 1.8205 - accuracy: 0.5309 - val_loss: 1.9373 - val_accuracy: 0.5276
# Epoch 17/30
# 455/455 [==============================] - ETA: 0s - loss: 1.8367 - accuracy: 0.5351
# Epoch 17: val_accuracy did not improve from 0.52755
# 455/455 [==============================] - 469s 1s/step - loss: 1.8367 - accuracy: 0.5351 - val_loss: 1.9394 - val_accuracy: 0.5211
# Epoch 18/30
# 455/455 [==============================] - ETA: 0s - loss: 1.7870 - accuracy: 0.5389
# Epoch 18: val_accuracy did not improve from 0.52755
# 455/455 [==============================] - 471s 1s/step - loss: 1.7870 - accuracy: 0.5389 - val_loss: 1.8696 - val_accuracy: 0.4876
# Epoch 19/30
# 455/455 [==============================] - ETA: 0s - loss: 1.7445 - accuracy: 0.5476
# Epoch 19: val_accuracy did not improve from 0.52755
# 455/455 [==============================] - 472s 1s/step - loss: 1.7445 - accuracy: 0.5476 - val_loss: 1.7687 - val_accuracy: 0.5155
# Epoch 20/30
# 455/455 [==============================] - ETA: 0s - loss: 1.7217 - accuracy: 0.5502
# Epoch 20: val_accuracy did not improve from 0.52755
# 455/455 [==============================] - 470s 1s/step - loss: 1.7217 - accuracy: 0.5502 - val_loss: 1.7452 - val_accuracy: 0.5201
# Epoch 21/30
# 455/455 [==============================] - ETA: 0s - loss: 1.6675 - accuracy: 0.5497
# Epoch 21: val_accuracy improved from 0.52755 to 0.53746, saving model to AML/best_model.h5
# 455/455 [==============================] - 475s 1s/step - loss: 1.6675 - accuracy: 0.5497 - val_loss: 1.7175 - val_accuracy: 0.5375
# Epoch 22/30
# 455/455 [==============================] - ETA: 0s - loss: 1.6798 - accuracy: 0.5572
# Epoch 22: val_accuracy improved from 0.53746 to 0.55325, saving model to AML/best_model.h5
# 455/455 [==============================] - 587s 1s/step - loss: 1.6798 - accuracy: 0.5572 - val_loss: 1.5873 - val_accuracy: 0.5533
# Epoch 23/30
# 455/455 [==============================] - ETA: 0s - loss: 1.6355 - accuracy: 0.5617
# Epoch 23: val_accuracy improved from 0.55325 to 0.56409, saving model to AML/best_model.h5
# 455/455 [==============================] - 618s 1s/step - loss: 1.6355 - accuracy: 0.5617 - val_loss: 1.6729 - val_accuracy: 0.5641
# Epoch 24/30
# 455/455 [==============================] - ETA: 0s - loss: 1.6054 - accuracy: 0.5590
# Epoch 24: val_accuracy did not improve from 0.56409
# 455/455 [==============================] - 491s 1s/step - loss: 1.6054 - accuracy: 0.5590 - val_loss: 1.6026 - val_accuracy: 0.5563
# Epoch 25/30
# 455/455 [==============================] - ETA: 0s - loss: 1.5996 - accuracy: 0.5611
# Epoch 25: val_accuracy improved from 0.56409 to 0.56842, saving model to AML/best_model.h5
# 455/455 [==============================] - 473s 1s/step - loss: 1.5996 - accuracy: 0.5611 - val_loss: 1.5749 - val_accuracy: 0.5684
# Epoch 26/30
# 455/455 [==============================] - ETA: 0s - loss: 1.5680 - accuracy: 0.5624
# Epoch 26: val_accuracy improved from 0.56842 to 0.57492, saving model to AML/best_model.h5
# 455/455 [==============================] - 485s 1s/step - loss: 1.5680 - accuracy: 0.5624 - val_loss: 1.5732 - val_accuracy: 0.5749
# Epoch 27/30
# 455/455 [==============================] - ETA: 0s - loss: 1.5440 - accuracy: 0.5659
# Epoch 27: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 526s 1s/step - loss: 1.5440 - accuracy: 0.5659 - val_loss: 1.6728 - val_accuracy: 0.5344
# Epoch 28/30
# 455/455 [==============================] - ETA: 0s - loss: 1.5093 - accuracy: 0.5680
# Epoch 28: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 566s 1s/step - loss: 1.5093 - accuracy: 0.5680 - val_loss: 1.5023 - val_accuracy: 0.5678
# Epoch 29/30
# 455/455 [==============================] - ETA: 0s - loss: 1.4895 - accuracy: 0.5728
# Epoch 29: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 527s 1s/step - loss: 1.4895 - accuracy: 0.5728 - val_loss: 1.4855 - val_accuracy: 0.5650
# Epoch 30/30
# 455/455 [==============================] - ETA: 0s - loss: 1.4991 - accuracy: 0.5725
# Epoch 30: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 517s 1s/step - loss: 1.4991 - accuracy: 0.5725 - val_loss: 1.4713 - val_accuracy: 0.5607

# %%
model.save('AML_model_firsttrain.h5')

# %%
import pickle

# save the model as a pickle file
model_pkl_file = "CNN_model.pkl"  

with open(model_pkl_file, 'wb') as file:  
    pickle.dump(model, file)

# %%
# visualizing

plt.plot(history.history["loss"],'r',label = "Training Loss")

plt.plot(history.history["val_loss"],'b', label = "Validation Loss")

plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label = "Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label = "Validataion Accuracy")
plt.legend()

# %%
loss = model.evaluate(X_test, y_test)
print("Test Acc: " + str(loss[1]))
# Out:
# 113/113 [==============================] - 19s 163ms/step - loss: 1.4123 - accuracy: 0.5929
# Test Acc: 0.5929228067398071

# %%
preds = model.predict(X_test)
y_pred = np.argmax(preds, axis = 1)
# Out:
# 113/113 [==============================] - 17s 146ms/step

# %%
label_dict = {0 : 'Angry', 1 : 'Fear', 2 : 'Happiness', 3 : 'Sad', 4 : 'Neutral'} # label_dict: a Python dictionary that maps the integer label indices (0-6) to their corresponding string labels.

figure = plt.figure(figsize=(20, 8)) # figure: the matplotlib figure object that will be used to display the images and labels., plt.figure(figsize=(20, 8)): this creates a new figure object with a specified size of 20 x 8 inches.

for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)): # i: the index of the current subplot in the figure., index: a randomly selected index from the test set used to display an example image and its predicted and true labels. np.random.choice(X_test.shape[0], size=24, replace=False): this randomly selects 24 indices from the test set without replacement.
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[]) # ax: the matplotlib Axes object representing the current subplot in the figure.figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[]): this adds a new subplot to the figure, with 4 rows and 6 columns of subplots. The i + 1 argument specifies the index of the current subplot in the figure, and xticks=[] and yticks=[] remove the tick marks on the x and y axes.

    ax.imshow(np.squeeze(X_test[index])) # ax.imshow(): this displays the image on the subplot. np.squeeze(X_test[index]): this removes any single-dimensional entries from the shape of X_test[index] to ensure that the image is displayed properly.

    predict_index = label_dict[(y_pred[index])] # the predicted label for the current example image, obtained by mapping the predicted label index y_pred[index] to its corresponding string label using the label_dict dictionary.

    true_index = label_dict[np.argmax(y_test,axis=1)[index]] # true_index: the true label for the current example image, obtained by finding the index of the maximum value in the ground truth label y_test[index], and then mapping that index to its corresponding string label using the label_dict dictionary.


    '''
    ax.set_title(): this adds a title to the subplot.
    "{} ({})".format((predict_index), (true_index)): the title string that will be displayed on the subplot, which includes the predicted and true labels for the current example image.
    '''
    ax.set_title("{} ({})".format((predict_index),
                                  (true_index)),
                                  color=("green" if predict_index == true_index else "red")) # the color of the title text, which is green if the predicted and true labels are the same, and red otherwise.

# %%
CLASS_LABELS  = ['Anger','Fear','Happy','Sadness', 'Neutral']

cm_data = confusion_matrix(np.argmax(y_test, axis = 1), y_pred)

cm = pd.DataFrame(cm_data, columns = CLASS_LABELS, index= CLASS_LABELS)
cm.index.name = 'Actual'
cm.columns.name = 'Predicted'

plt.figure(figsize = (15,10))

plt.title('Confusion Matrix', fontsize = 20)
sns.set(font_scale = 1.2)

ax = sns.heatmap(cm, cbar = False, cmap = "Blues", annot = True, annot_kws = {"size":16}, fmt = 'g')

# %%
from sklearn.metrics import classification_report

print(classification_report(np.argmax(y_test, axis = 1), y_pred, digits = 3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.575     0.491     0.530       525
#            1      0.611     0.044     0.082       499
#            2      0.690     0.885     0.776      1333
#            3      0.461     0.406     0.432       571
#            4      0.489     0.660     0.561       661
#
#     accuracy                          0.593      3589
#    macro avg      0.565     0.497     0.476      3589
# weighted avg      0.589     0.593     0.549      3589

# %%
# Fine Tuning
model = cnn_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(0.001), #increasing the learning rate to 0.001 from 0.0001
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
history = model.fit(train_generator, # a data generator that generates batches of training data during training. The data generator was created using the Keras ImageDataGenerator class, which generates augmented images in real-time as the model is training.
                    epochs=30, # the number of epochs (iterations over the entire training set) to train the model for. In this case, the model will be trained for 30 epochs.
                    batch_size=64,  #  the number of training examples to process at once during each training step. In this case, the batch size is set to 64.
                    verbose=1, # this specifies the level of detail to print during training. In this case, verbose=1 will print out progress updates during training for each epoch.
                    callbacks=[checkpointer], #  a list of callbacks to apply during training. In this case, the checkpointer callback is used to save the weights of the best performing model on the validation set.
                    validation_data=val_generator) # a data generator that generates batches of validation data during training. The validation data is used to monitor the model's performance on data that it has not seen during training.

'''
This code is training the compiled CNN model using the Keras fit method, which fits the model to the training data and returns a history object that contains information about the training process.
'''
# Out:
# Epoch 1/30
# 455/455 [==============================] - ETA: 0s - loss: 14.3756 - accuracy: 0.2272
# Epoch 1: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 562s 1s/step - loss: 14.3756 - accuracy: 0.2272 - val_loss: 13.6734 - val_accuracy: 0.3080
# Epoch 2/30
# 455/455 [==============================] - ETA: 0s - loss: 13.9710 - accuracy: 0.2399
# Epoch 2: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 573s 1s/step - loss: 13.9710 - accuracy: 0.2399 - val_loss: 13.4509 - val_accuracy: 0.3226
# Epoch 3/30
# 455/455 [==============================] - ETA: 0s - loss: 13.6550 - accuracy: 0.2529
# Epoch 3: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 529s 1s/step - loss: 13.6550 - accuracy: 0.2529 - val_loss: 13.2337 - val_accuracy: 0.3427
# Epoch 4/30
# 455/455 [==============================] - ETA: 0s - loss: 13.3847 - accuracy: 0.2598
# Epoch 4: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 503s 1s/step - loss: 13.3847 - accuracy: 0.2598 - val_loss: 12.9912 - val_accuracy: 0.3492
# Epoch 5/30
# 455/455 [==============================] - ETA: 0s - loss: 13.1268 - accuracy: 0.2680
# Epoch 5: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 494s 1s/step - loss: 13.1268 - accuracy: 0.2680 - val_loss: 12.7955 - val_accuracy: 0.3437
# Epoch 6/30
# 455/455 [==============================] - ETA: 0s - loss: 12.9005 - accuracy: 0.2781
# Epoch 6: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 473s 1s/step - loss: 12.9005 - accuracy: 0.2781 - val_loss: 12.5847 - val_accuracy: 0.3517
# Epoch 7/30
# 455/455 [==============================] - ETA: 0s - loss: 12.6637 - accuracy: 0.2904
# Epoch 7: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 12.6637 - accuracy: 0.2904 - val_loss: 12.3749 - val_accuracy: 0.3598
# Epoch 8/30
# 455/455 [==============================] - ETA: 0s - loss: 12.4457 - accuracy: 0.2957
# Epoch 8: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 12.4457 - accuracy: 0.2957 - val_loss: 12.1846 - val_accuracy: 0.3607
# Epoch 9/30
# 455/455 [==============================] - ETA: 0s - loss: 12.2333 - accuracy: 0.3019
# Epoch 9: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 12.2333 - accuracy: 0.3019 - val_loss: 11.9927 - val_accuracy: 0.3576
# Epoch 10/30
# 455/455 [==============================] - ETA: 0s - loss: 12.0348 - accuracy: 0.3062
# Epoch 10: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 12.0348 - accuracy: 0.3062 - val_loss: 11.7977 - val_accuracy: 0.3613
# Epoch 11/30
# 455/455 [==============================] - ETA: 0s - loss: 11.8377 - accuracy: 0.3070
# Epoch 11: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 463s 1s/step - loss: 11.8377 - accuracy: 0.3070 - val_loss: 11.6172 - val_accuracy: 0.3570
# Epoch 12/30
# 455/455 [==============================] - ETA: 0s - loss: 11.6329 - accuracy: 0.3184
# Epoch 12: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 463s 1s/step - loss: 11.6329 - accuracy: 0.3184 - val_loss: 11.4294 - val_accuracy: 0.3610
# Epoch 13/30
# 455/455 [==============================] - ETA: 0s - loss: 11.4409 - accuracy: 0.3206
# Epoch 13: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 463s 1s/step - loss: 11.4409 - accuracy: 0.3206 - val_loss: 11.2507 - val_accuracy: 0.3560
# Epoch 14/30
# 455/455 [==============================] - ETA: 0s - loss: 11.2610 - accuracy: 0.3219
# Epoch 14: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 11.2610 - accuracy: 0.3219 - val_loss: 11.0742 - val_accuracy: 0.3610
# Epoch 15/30
# 455/455 [==============================] - ETA: 0s - loss: 11.0766 - accuracy: 0.3258
# Epoch 15: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 463s 1s/step - loss: 11.0766 - accuracy: 0.3258 - val_loss: 10.8973 - val_accuracy: 0.3625
# Epoch 16/30
# 455/455 [==============================] - ETA: 0s - loss: 10.8983 - accuracy: 0.3258
# Epoch 16: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 10.8983 - accuracy: 0.3258 - val_loss: 10.7293 - val_accuracy: 0.3594
# Epoch 17/30
# 455/455 [==============================] - ETA: 0s - loss: 10.7214 - accuracy: 0.3324
# Epoch 17: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 10.7214 - accuracy: 0.3324 - val_loss: 10.5650 - val_accuracy: 0.3616
# Epoch 18/30
# 455/455 [==============================] - ETA: 0s - loss: 10.5478 - accuracy: 0.3381
# Epoch 18: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 10.5478 - accuracy: 0.3381 - val_loss: 10.4000 - val_accuracy: 0.3638
# Epoch 19/30
# 455/455 [==============================] - ETA: 0s - loss: 10.3841 - accuracy: 0.3399
# Epoch 19: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 10.3841 - accuracy: 0.3399 - val_loss: 10.2371 - val_accuracy: 0.3641
# Epoch 20/30
# 455/455 [==============================] - ETA: 0s - loss: 10.2186 - accuracy: 0.3418
# Epoch 20: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 10.2186 - accuracy: 0.3418 - val_loss: 10.0792 - val_accuracy: 0.3638
# Epoch 21/30
# 455/455 [==============================] - ETA: 0s - loss: 10.0594 - accuracy: 0.3427
# Epoch 21: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 10.0594 - accuracy: 0.3427 - val_loss: 9.9260 - val_accuracy: 0.3653
# Epoch 22/30
# 455/455 [==============================] - ETA: 0s - loss: 9.8971 - accuracy: 0.3468
# Epoch 22: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.8971 - accuracy: 0.3468 - val_loss: 9.7721 - val_accuracy: 0.3613
# Epoch 23/30
# 455/455 [==============================] - ETA: 0s - loss: 9.7414 - accuracy: 0.3442
# Epoch 23: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 9.7414 - accuracy: 0.3442 - val_loss: 9.6161 - val_accuracy: 0.3576
# Epoch 24/30
# 455/455 [==============================] - ETA: 0s - loss: 9.5911 - accuracy: 0.3496
# Epoch 24: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.5911 - accuracy: 0.3496 - val_loss: 9.4701 - val_accuracy: 0.3647
# Epoch 25/30
# 455/455 [==============================] - ETA: 0s - loss: 9.4412 - accuracy: 0.3491
# Epoch 25: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.4412 - accuracy: 0.3491 - val_loss: 9.3248 - val_accuracy: 0.3672
# Epoch 26/30
# 455/455 [==============================] - ETA: 0s - loss: 9.2954 - accuracy: 0.3543
# Epoch 26: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.2954 - accuracy: 0.3543 - val_loss: 9.1829 - val_accuracy: 0.3625
# Epoch 27/30
# 455/455 [==============================] - ETA: 0s - loss: 9.1536 - accuracy: 0.3523
# Epoch 27: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.1536 - accuracy: 0.3523 - val_loss: 9.0451 - val_accuracy: 0.3625
# Epoch 28/30
# 455/455 [==============================] - ETA: 0s - loss: 9.0108 - accuracy: 0.3572
# Epoch 28: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 9.0108 - accuracy: 0.3572 - val_loss: 8.9028 - val_accuracy: 0.3641
# Epoch 29/30
# 455/455 [==============================] - ETA: 0s - loss: 8.8706 - accuracy: 0.3573
# Epoch 29: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 462s 1s/step - loss: 8.8706 - accuracy: 0.3573 - val_loss: 8.7679 - val_accuracy: 0.3644
# Epoch 30/30
# 455/455 [==============================] - ETA: 0s - loss: 8.7346 - accuracy: 0.3573
# Epoch 30: val_accuracy did not improve from 0.57492
# 455/455 [==============================] - 461s 1s/step - loss: 8.7346 - accuracy: 0.3573 - val_loss: 8.6303 - val_accuracy: 0.3762
# '\nThis code is training the compiled CNN model using the Keras fit method, which fits the model to the training data and returns a history object that contains information about the training process.\n'

# %%
loss = model.evaluate(X_test,y_test)
print("Test Acc: "+ str(loss[1]))
# Out:
# 113/113 [==============================] - 15s 128ms/step - loss: 8.6051 - accuracy: 0.3831
# Test Acc: 0.38311508297920227

# %%
# model.save('AML_model_2.h5')

# %%
plt.plot(history.history["loss"],'r',label = "Training Loss")
plt.plot(history.history["val_loss"],'b',label = "Validation Loss")
plt.legend()

# %%
plt.plot(history.history["accuracy"],'r',label = "Training Accuracy")
plt.plot(history.history["val_accuracy"],'b',label = "Validation Accuracy")
plt.legend()

# %%
#changing epoch numbers

model = cnn_model()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.compile( # the CNN model instance that was created using cnn_model().
    optimizer = Adam(lr=0.0001),  #  the optimizer to use during training. In this case, Adam is used with a learning rate of 0.0001. The optimizer is responsible for updating the model parameters during training in order to minimize the loss function.
    loss='categorical_crossentropy',  # the loss function to use during training. In this case, categorical cross-entropy is used, which is a common loss function used for multi-class classification problems.
    metrics=['accuracy']) #  the evaluation metric(s) to use during training and testing. In this case, only accuracy is used as the metric, which is a measure of the model's ability to correctly classify input examples. During training, the model will be optimized to maximize accuracy, and during testing, the accuracy will be reported to evaluate the model's performance on the test set.
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
checkpointer = [EarlyStopping(monitor = 'val_accuracy',
                             verbose = 1,
                             restore_best_weights = True,
                             mode = "max",
                             patience = 10), #increased to 10

                ModelCheckpoint('best_model.h5',
                              monitor = "val_accuracy",
                              verbose = 1,
                              save_best_only = True,
                              mode = "max")

               ]

# %%
history = model.fit(train_generator,
                   epochs = 50, #increased no of epochs to 50
                   batch_size = 64,
                   verbose = 1,
                   callbacks = [checkpointer],
                   validation_data = val_generator)
# Out:
# Epoch 1/50
# 455/455 [==============================] - ETA: 0s - loss: 6.3861 - accuracy: 0.2892
# Epoch 1: val_accuracy improved from -inf to 0.35697, saving model to best_model.h5
# 455/455 [==============================] - 469s 1s/step - loss: 6.3861 - accuracy: 0.2892 - val_loss: 2.1638 - val_accuracy: 0.3570
# Epoch 2/50
# 455/455 [==============================] - ETA: 0s - loss: 2.0001 - accuracy: 0.3302
# Epoch 2: val_accuracy did not improve from 0.35697
# 455/455 [==============================] - 463s 1s/step - loss: 2.0001 - accuracy: 0.3302 - val_loss: 1.8346 - val_accuracy: 0.3529
# Epoch 3/50
# 455/455 [==============================] - ETA: 0s - loss: 1.9446 - accuracy: 0.3480
# Epoch 3: val_accuracy did not improve from 0.35697
# 455/455 [==============================] - 465s 1s/step - loss: 1.9446 - accuracy: 0.3480 - val_loss: 2.0868 - val_accuracy: 0.3350
# Epoch 4/50
# 455/455 [==============================] - ETA: 0s - loss: 1.9142 - accuracy: 0.3587
# Epoch 4: val_accuracy improved from 0.35697 to 0.36161, saving model to best_model.h5
# 455/455 [==============================] - 466s 1s/step - loss: 1.9142 - accuracy: 0.3587 - val_loss: 1.9519 - val_accuracy: 0.3616
# Epoch 5/50
# 455/455 [==============================] - ETA: 0s - loss: 2.1478 - accuracy: 0.3938
# Epoch 5: val_accuracy did not improve from 0.36161
# 455/455 [==============================] - 466s 1s/step - loss: 2.1478 - accuracy: 0.3938 - val_loss: 2.3174 - val_accuracy: 0.3607
# Epoch 6/50
# 455/455 [==============================] - ETA: 0s - loss: 2.3644 - accuracy: 0.4478
# Epoch 6: val_accuracy improved from 0.36161 to 0.43808, saving model to best_model.h5
# 455/455 [==============================] - 465s 1s/step - loss: 2.3644 - accuracy: 0.4478 - val_loss: 2.4140 - val_accuracy: 0.4381
# Epoch 7/50
# 455/455 [==============================] - ETA: 0s - loss: 2.3428 - accuracy: 0.4756
# Epoch 7: val_accuracy improved from 0.43808 to 0.43870, saving model to best_model.h5
# 455/455 [==============================] - 464s 1s/step - loss: 2.3428 - accuracy: 0.4756 - val_loss: 2.4692 - val_accuracy: 0.4387
# Epoch 8/50
# 455/455 [==============================] - ETA: 0s - loss: 2.2181 - accuracy: 0.4937
# Epoch 8: val_accuracy improved from 0.43870 to 0.47337, saving model to best_model.h5
# 455/455 [==============================] - 464s 1s/step - loss: 2.2181 - accuracy: 0.4937 - val_loss: 2.1664 - val_accuracy: 0.4734
# Epoch 9/50
# 455/455 [==============================] - ETA: 0s - loss: 2.1520 - accuracy: 0.5010
# Epoch 9: val_accuracy did not improve from 0.47337
# 455/455 [==============================] - 463s 1s/step - loss: 2.1520 - accuracy: 0.5010 - val_loss: 2.1507 - val_accuracy: 0.4514
# Epoch 10/50
# 455/455 [==============================] - ETA: 0s - loss: 2.0583 - accuracy: 0.5063
# Epoch 10: val_accuracy did not improve from 0.47337
# 455/455 [==============================] - 463s 1s/step - loss: 2.0583 - accuracy: 0.5063 - val_loss: 2.1379 - val_accuracy: 0.4322
# Epoch 11/50
# 455/455 [==============================] - ETA: 0s - loss: 1.9602 - accuracy: 0.5191
# Epoch 11: val_accuracy improved from 0.47337 to 0.51765, saving model to best_model.h5
# 455/455 [==============================] - 463s 1s/step - loss: 1.9602 - accuracy: 0.5191 - val_loss: 2.0555 - val_accuracy: 0.5176
# Epoch 12/50
# 455/455 [==============================] - ETA: 0s - loss: 1.9513 - accuracy: 0.5235
# Epoch 12: val_accuracy did not improve from 0.51765
# 455/455 [==============================] - 463s 1s/step - loss: 1.9513 - accuracy: 0.5235 - val_loss: 2.0929 - val_accuracy: 0.4511
# Epoch 13/50
# 455/455 [==============================] - ETA: 0s - loss: 1.9565 - accuracy: 0.5265
# Epoch 13: val_accuracy did not improve from 0.51765
# 455/455 [==============================] - 463s 1s/step - loss: 1.9565 - accuracy: 0.5265 - val_loss: 1.8916 - val_accuracy: 0.5056
# Epoch 14/50
# 455/455 [==============================] - ETA: 0s - loss: 1.8796 - accuracy: 0.5353
# Epoch 14: val_accuracy improved from 0.51765 to 0.54520, saving model to best_model.h5
# 455/455 [==============================] - 463s 1s/step - loss: 1.8796 - accuracy: 0.5353 - val_loss: 1.9582 - val_accuracy: 0.5452
# Epoch 15/50
# 455/455 [==============================] - ETA: 0s - loss: 1.8751 - accuracy: 0.5368
# Epoch 15: val_accuracy did not improve from 0.54520
# 455/455 [==============================] - 463s 1s/step - loss: 1.8751 - accuracy: 0.5368 - val_loss: 1.8556 - val_accuracy: 0.5319
# Epoch 16/50
# 455/455 [==============================] - ETA: 0s - loss: 1.8083 - accuracy: 0.5395
# Epoch 16: val_accuracy did not improve from 0.54520
# 455/455 [==============================] - 463s 1s/step - loss: 1.8083 - accuracy: 0.5395 - val_loss: 1.8552 - val_accuracy: 0.5146
# Epoch 17/50
# 455/455 [==============================] - ETA: 0s - loss: 1.7968 - accuracy: 0.5462
# Epoch 17: val_accuracy improved from 0.54520 to 0.55635, saving model to best_model.h5
# 455/455 [==============================] - 464s 1s/step - loss: 1.7968 - accuracy: 0.5462 - val_loss: 1.8108 - val_accuracy: 0.5563
# Epoch 18/50
# 455/455 [==============================] - ETA: 0s - loss: 1.7956 - accuracy: 0.5464
# Epoch 18: val_accuracy improved from 0.55635 to 0.57461, saving model to best_model.h5
# 455/455 [==============================] - 464s 1s/step - loss: 1.7956 - accuracy: 0.5464 - val_loss: 1.7598 - val_accuracy: 0.5746
# Epoch 19/50
# 455/455 [==============================] - ETA: 0s - loss: 1.7075 - accuracy: 0.5526
# Epoch 19: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 464s 1s/step - loss: 1.7075 - accuracy: 0.5526 - val_loss: 1.7232 - val_accuracy: 0.5461
# Epoch 20/50
# 455/455 [==============================] - ETA: 0s - loss: 1.6898 - accuracy: 0.5571
# Epoch 20: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 463s 1s/step - loss: 1.6898 - accuracy: 0.5571 - val_loss: 1.6367 - val_accuracy: 0.5653
# Epoch 21/50
# 455/455 [==============================] - ETA: 0s - loss: 1.6614 - accuracy: 0.5628
# Epoch 21: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 464s 1s/step - loss: 1.6614 - accuracy: 0.5628 - val_loss: 1.6526 - val_accuracy: 0.5449
# Epoch 22/50
# 455/455 [==============================] - ETA: 0s - loss: 1.6184 - accuracy: 0.5614
# Epoch 22: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 465s 1s/step - loss: 1.6184 - accuracy: 0.5614 - val_loss: 1.6684 - val_accuracy: 0.5440
# Epoch 23/50
# 455/455 [==============================] - ETA: 0s - loss: 1.6293 - accuracy: 0.5646
# Epoch 23: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 464s 1s/step - loss: 1.6293 - accuracy: 0.5646 - val_loss: 1.6742 - val_accuracy: 0.5557
# Epoch 24/50
# 455/455 [==============================] - ETA: 0s - loss: 1.6197 - accuracy: 0.5646
# Epoch 24: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 464s 1s/step - loss: 1.6197 - accuracy: 0.5646 - val_loss: 1.5546 - val_accuracy: 0.5616
# Epoch 25/50
# 455/455 [==============================] - ETA: 0s - loss: 1.5799 - accuracy: 0.5662
# Epoch 25: val_accuracy did not improve from 0.57461
# 455/455 [==============================] - 464s 1s/step - loss: 1.5799 - accuracy: 0.5662 - val_loss: 1.5194 - val_accuracy: 0.5638
# Epoch 26/50
# 455/455 [==============================] - ETA: 0s - loss: 1.5460 - accuracy: 0.5690
# Epoch 26: val_accuracy improved from 0.57461 to 0.58576, saving model to best_model.h5
# 455/455 [==============================] - 464s 1s/step - loss: 1.5460 - accuracy: 0.5690 - val_loss: 1.5033 - val_accuracy: 0.5858
# Epoch 27/50
# 455/455 [==============================] - ETA: 0s - loss: 1.5458 - accuracy: 0.5679
# Epoch 27: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 464s 1s/step - loss: 1.5458 - accuracy: 0.5679 - val_loss: 1.4715 - val_accuracy: 0.5715
# Epoch 28/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4973 - accuracy: 0.5737
# Epoch 28: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 470s 1s/step - loss: 1.4973 - accuracy: 0.5737 - val_loss: 1.4970 - val_accuracy: 0.5783
# Epoch 29/50
# 455/455 [==============================] - ETA: 0s - loss: 1.5024 - accuracy: 0.5732
# Epoch 29: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 470s 1s/step - loss: 1.5024 - accuracy: 0.5732 - val_loss: 1.5243 - val_accuracy: 0.5666
# Epoch 30/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4833 - accuracy: 0.5763
# Epoch 30: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 482s 1s/step - loss: 1.4833 - accuracy: 0.5763 - val_loss: 1.5019 - val_accuracy: 0.5622
# Epoch 31/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4730 - accuracy: 0.5771
# Epoch 31: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 479s 1s/step - loss: 1.4730 - accuracy: 0.5771 - val_loss: 1.5901 - val_accuracy: 0.5440
# Epoch 32/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4593 - accuracy: 0.5784
# Epoch 32: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 500s 1s/step - loss: 1.4593 - accuracy: 0.5784 - val_loss: 1.4429 - val_accuracy: 0.5780
# Epoch 33/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4396 - accuracy: 0.5810
# Epoch 33: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 464s 1s/step - loss: 1.4396 - accuracy: 0.5810 - val_loss: 1.4439 - val_accuracy: 0.5684
# Epoch 34/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4297 - accuracy: 0.5801
# Epoch 34: val_accuracy did not improve from 0.58576
# 455/455 [==============================] - 469s 1s/step - loss: 1.4297 - accuracy: 0.5801 - val_loss: 1.4799 - val_accuracy: 0.5415
# Epoch 35/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4012 - accuracy: 0.5826
# Epoch 35: val_accuracy improved from 0.58576 to 0.59071, saving model to best_model.h5
# 455/455 [==============================] - 476s 1s/step - loss: 1.4012 - accuracy: 0.5826 - val_loss: 1.3933 - val_accuracy: 0.5907
# Epoch 36/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4127 - accuracy: 0.5873
# Epoch 36: val_accuracy did not improve from 0.59071
# 455/455 [==============================] - 481s 1s/step - loss: 1.4127 - accuracy: 0.5873 - val_loss: 1.4938 - val_accuracy: 0.5526
# Epoch 37/50
# 455/455 [==============================] - ETA: 0s - loss: 1.4095 - accuracy: 0.5776
# Epoch 37: val_accuracy improved from 0.59071 to 0.59288, saving model to best_model.h5
# 455/455 [==============================] - 474s 1s/step - loss: 1.4095 - accuracy: 0.5776 - val_loss: 1.3879 - val_accuracy: 0.5929
# Epoch 38/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3753 - accuracy: 0.5871
# Epoch 38: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 473s 1s/step - loss: 1.3753 - accuracy: 0.5871 - val_loss: 1.3806 - val_accuracy: 0.5898
# Epoch 39/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3722 - accuracy: 0.5867
# Epoch 39: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 473s 1s/step - loss: 1.3722 - accuracy: 0.5867 - val_loss: 1.3433 - val_accuracy: 0.5895
# Epoch 40/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3657 - accuracy: 0.5919
# Epoch 40: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 506s 1s/step - loss: 1.3657 - accuracy: 0.5919 - val_loss: 1.4194 - val_accuracy: 0.5613
# Epoch 41/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3550 - accuracy: 0.5861
# Epoch 41: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 471s 1s/step - loss: 1.3550 - accuracy: 0.5861 - val_loss: 1.3193 - val_accuracy: 0.5898
# Epoch 42/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3479 - accuracy: 0.5894
# Epoch 42: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 481s 1s/step - loss: 1.3479 - accuracy: 0.5894 - val_loss: 1.3555 - val_accuracy: 0.5848
# Epoch 43/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3470 - accuracy: 0.5914
# Epoch 43: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 490s 1s/step - loss: 1.3470 - accuracy: 0.5914 - val_loss: 1.3386 - val_accuracy: 0.5851
# Epoch 44/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3365 - accuracy: 0.5954
# Epoch 44: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 520s 1s/step - loss: 1.3365 - accuracy: 0.5954 - val_loss: 1.4291 - val_accuracy: 0.5570
# Epoch 45/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3408 - accuracy: 0.5943
# Epoch 45: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 477s 1s/step - loss: 1.3408 - accuracy: 0.5943 - val_loss: 1.3464 - val_accuracy: 0.5898
# Epoch 46/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3465 - accuracy: 0.5937
# Epoch 46: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 471s 1s/step - loss: 1.3465 - accuracy: 0.5937 - val_loss: 1.3532 - val_accuracy: 0.5669
# Epoch 47/50
# 455/455 [==============================] - ETA: 0s - loss: 1.3343 - accuracy: 0.5945Restoring model weights from the end of the best epoch: 37.
#
# Epoch 47: val_accuracy did not improve from 0.59288
# 455/455 [==============================] - 472s 1s/step - loss: 1.3343 - accuracy: 0.5945 - val_loss: 1.3289 - val_accuracy: 0.5895
# Epoch 47: early stopping

# %%
loss = model.evaluate(X_test,y_test)
print("Test Acc: " + str(loss[1]))
# Out:
# 113/113 [==============================] - 15s 130ms/step - loss: 1.3842 - accuracy: 0.5918
# Test Acc: 0.5918083190917969

# %%
model.save('AML_model_3.h5')

# %%
label_dict = {0 : 'Angry', 1 : 'Fear', 2 : 'Happiness', 3 : 'Sad', 4 : 'Neutral'} # label_dict: a Python dictionary that maps the integer label indices (0-6) to their corresponding string labels.

figure = plt.figure(figsize=(20, 8)) # figure: the matplotlib figure object that will be used to display the images and labels., plt.figure(figsize=(20, 8)): this creates a new figure object with a specified size of 20 x 8 inches.

for i, index in enumerate(np.random.choice(X_test.shape[0], size=24, replace=False)): # i: the index of the current subplot in the figure., index: a randomly selected index from the test set used to display an example image and its predicted and true labels. np.random.choice(X_test.shape[0], size=24, replace=False): this randomly selects 24 indices from the test set without replacement.
    ax = figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[]) # ax: the matplotlib Axes object representing the current subplot in the figure.figure.add_subplot(4, 6, i + 1, xticks=[], yticks=[]): this adds a new subplot to the figure, with 4 rows and 6 columns of subplots. The i + 1 argument specifies the index of the current subplot in the figure, and xticks=[] and yticks=[] remove the tick marks on the x and y axes.

    ax.imshow(np.squeeze(X_test[index])) # ax.imshow(): this displays the image on the subplot. np.squeeze(X_test[index]): this removes any single-dimensional entries from the shape of X_test[index] to ensure that the image is displayed properly.

    predict_index = label_dict[(y_pred[index])] # the predicted label for the current example image, obtained by mapping the predicted label index y_pred[index] to its corresponding string label using the label_dict dictionary.

    true_index = label_dict[np.argmax(y_test,axis=1)[index]] # true_index: the true label for the current example image, obtained by finding the index of the maximum value in the ground truth label y_test[index], and then mapping that index to its corresponding string label using the label_dict dictionary.


    '''
    ax.set_title(): this adds a title to the subplot.
    "{} ({})".format((predict_index), (true_index)): the title string that will be displayed on the subplot, which includes the predicted and true labels for the current example image.
    '''
    ax.set_title("{} ({})".format((predict_index),
                                  (true_index)),
                                  color=("green" if predict_index == true_index else "red")) # the color of the title text, which is green if the predicted and true labels are the same, and red otherwise.

# %%
model.save('AML_model_4.h5')
